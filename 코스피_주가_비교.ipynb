# %% [markdown]
# <a href="https://colab.research.google.com/github/yy0750/KOSPI200-Components-Direction-Prediction/blob/main/%EC%BD%94%EC%8A%A4%ED%94%BC_%EC%A3%BC%EA%B0%80_%EB%B9%84%EA%B5%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finance-datareader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 540.8 kB/s eta 0:00:00
# ...

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
a = fdr.DataReader('005930', '2004-01-01', '2023-12-31')

# %%
import FinanceDataReader as fdr
import pandas as pd

# 코스피200 지수의 코드
kospi200_code = 'KS200'

# 데이터 가져오기 기간 설정
start_date = '2023-01-01'
end_date = '2023-12-31'

# 코스피200 지수 데이터 가져오기 (기간 설정)
fdr_data = fdr.DataReader(kospi200_code, start=start_date, end=end_date)

# 데이터 확인
fdr_data.head()
# Out:
#               Open    High     Low   Close     Volume  Change  UpDown  Comp  \
# Date
# 2023-01-02  292.90  294.02  289.19  289.79   92544049 -0.0045       2 -1.31
# 2023-01-03  290.64  290.95  284.32  289.58  106623597 -0.0007       2 -0.21
# 2023-01-04  288.34  296.70  287.94  295.98  109947475  0.0221       1  6.40
# 2023-01-05  297.65  299.69  296.01  297.87  137287857  0.0064       1  1.89
# 2023-01-06  296.69  303.10  296.40  301.53  121021827  0.0123       1  3.66
#
#                    Amount            MarCap
# Date
# 2023-01-02  3817327305505  1535786624843340
# 2023-01-03  4524745849460  1530480035423500
# 2023-01-04  5193513528314  1557422148946850
# 2023-01-05  6003133980930  1563535980673890
# 2023-01-06  5367994107791  1581913625677170

# %%
import FinanceDataReader as fdr
import pandas as pd
import matplotlib.pyplot as plt

# 코스피200 지수의 코드
kospi200_code = 'KS200'

# 데이터 가져오기 기간 설정
start_date = '2023-01-01'
end_date = '2023-12-31'

# 코스피200 지수 데이터 가져오기 (기간 설정)
fdr_data = fdr.DataReader(kospi200_code, start=start_date, end=end_date)

# 'Change' 열로부터 복리 계산
fdr_data['Cumulative'] = (1 + fdr_data['Change']).cumprod()

# 시작 값을 1로 설정
fdr_data['Cumulative'].iloc[0] = 1

# 복리 계산 결과 시각화
plt.figure(figsize=(10, 5))
plt.plot(fdr_data.index, fdr_data['Cumulative'], label='Cumulative Return')
plt.title('KOSPI 200 Index Cumulative Return in 2023')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.legend()
plt.grid(True)
plt.show()

# CSV 파일로 저장
csv_file_path = 'kospi200_data_2023.csv'
fdr_data.to_csv(csv_file_path)

print(f"Data saved to {csv_file_path}")
# Out:
# <ipython-input-7-9bcbee0d3833>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fdr_data['Cumulative'].iloc[0] = 1
# Data saved to kospi200_data_2023.csv

# %%
code = '005930'
fdr_data = fdr.DataReader(code)
fdr_data.head(20)
# Out:
#             Open  High   Low  Close   Volume    Change
# Date
# 2000-02-01  5600  5680  5260   5320  1429402       NaN
# 2000-02-02  5220  5370  5110   5250  1282143 -0.013158
# 2000-02-03  5250  5460  4970   5130  2855355 -0.022857
# 2000-02-07  5140  5330  5040   5240  1282835  0.021442
# 2000-02-08  5340  5480  5310   5430  1169244  0.036260
# 2000-02-09  5560  5720  5480   5720  1021023  0.053407
# 2000-02-10  5660  5880  5600   5760  1236979  0.006993
# 2000-02-11  5960  5960  5680   5700   693257 -0.010417
# 2000-02-14  5600  5660  5340   5380   882889 -0.056140
# 2000-02-15  5380  5420  5140   5200   766393 -0.033457
# 2000-02-16  5180  5200  4780   5000  1462389 -0.038462
# 2000-02-17  4939  5099  4910   5080  1303738  0.016000
# 2000-02-18  5370  5630  5160   5300  2175083  0.043307
# 2000-02-21  5200  5260  5030   5070   529722 -0.043396
# 2000-02-22  5000  5240  5000   5120   483669  0.009862
# 2000-02-23  5220  5260  5100   5140   554497  0.003906
# ...

# %%
import yfinance as yf
yahoo_data = yf.download('%s.KS' % code)
yahoo_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2000-01-04   6000.0   6110.0   5660.0   6110.0   4469.930176  74195000
# 2000-01-05   5800.0   6060.0   5520.0   5580.0   4082.195557  74680000
# 2000-01-06   5750.0   5780.0   5580.0   5620.0   4111.458984  54390000
# 2000-01-07   5560.0   5670.0   5360.0   5540.0   4052.932373  40305000
# 2000-01-10   5600.0   5770.0   5580.0   5770.0   4221.196289  46880000
# ...             ...      ...      ...      ...           ...       ...
# 2024-05-20  78100.0  79100.0  77900.0  78900.0  78900.000000  19456783
# 2024-05-21  78500.0  79000.0  78200.0  78400.0  78400.000000  13690583
# 2024-05-22  78100.0  78700.0  77300.0  77700.0  77700.000000  19521506
# 2024-05-23  77700.0  79100.0  77100.0  78300.0  78300.000000  18728087
# 2024-05-24  76800.0  77000.0  75700.0  75900.0  75900.000000  27891278
#
# [6114 rows x 6 columns]

# %%
pip install finance-datareader
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
code = '005930'
fdr_data = fdr.DataReader(code)
fdr_data.head(20)



corr = fdr_data.corr()

# 히트맵 생성
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
code = '005930'
fdr_data = fdr.DataReader(code)
fdr_data.head(20)



corr = fdr_data.corr()

# 히트맵 생성
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = yahoo_data.corr()

# 히트맵 생성
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
import requests
import pandas as pd

class KrxHistoricalDailyPriceDataDownloader:

    def __init__(self):
        self._headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36',
        }

        self._stocks = None
        self._stocks_delisted = None

        self._bld = 'dbms/MDC/STAT/standard/MDCSTAT01701'

    def get_stocks(self):
        data = {
            'mktsel': 'ALL',
            'typeNo': '0',
            'searchText': '',
            'bld': 'dbms/comm/finder/finder_stkisu',
        }
        url = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'
        response = requests.post(url, data, headers=self._headers)
        df = pd.json_normalize(response.json()['block1'])
        df = df.set_index('short_code')
        return df

    def get_stocks_delisted(self):
        data = {
            'mktsel': 'ALL',
            'searchText': '',
            'bld': 'dbms/comm/finder/finder_listdelisu',
        }
        url = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'
        response = requests.post(url, data, headers=self._headers)
        df = pd.json_normalize(response.json()['block1'])
        df = df.set_index('short_code')
        return df

    @property
    def stocks(self):
        if self._stocks is None:
            self._stocks = self.get_stocks()
        return self._stocks

    @property
    def stocks_delisted(self):
        if self._stocks_delisted is None:
            self._stocks_delisted = self.get_stocks_delisted()
        return self._stocks_delisted

    def get_full_code(self, symbol):
        if symbol in self.stocks.index:
            return self.stocks.loc[symbol]['full_code']
        if symbol in self.stocks_delisted.index:
            return self.stocks_delisted.loc[symbol]['full_code']
        raise ValueError('No full_code found for given symbol %s' % symbol)

    def download(self, symbol, start_date=None, end_date=None):
        if start_date is None:
            start_date = pd.Timestamp(1980, 1, 1)
        if end_date is None:
            end_date = pd.Timestamp.now().normalize() + pd.Timedelta(1, unit='day')

        full_code = self.get_full_code(symbol)

        url = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'
        data = {
            'bld': self._bld,
            'isuCd': full_code,
            'isuCd2': '',
            'strtDd': start_date.strftime("%Y%m%d"),
            'endDd': end_date.strftime("%Y%m%d"),
            'share': '1',
            'money': '1',
            'csvxls_isNo': 'false',
        }
        response = requests.post(url, data, headers=self._headers)
        df = pd.json_normalize(response.json()['output'])

        if df.shape[0] == 0:
            return None

        column_names = {
            'TRD_DD':'Date',
            'ISU_CD':'Code',
            'ISU_NM':'Name',
            'MKT_NM':'Market',
            'SECUGRP_NM':'SecuGroup',
            'TDD_CLSPRC':'Close',
            'FLUC_TP_CD':'UpDown',
            'CMPPRVDD_PRC':'Change',
            'FLUC_RT':'ChangeRate',
            'TDD_OPNPRC':'Open',
            'TDD_HGPRC':'High',
            'TDD_LWPRC':'Low',
            'ACC_TRDVOL':'Volume',
            'ACC_TRDVAL':'Amount',
            'MKTCAP':'MarCap',
            'CMPPREVDD_PRC': 'Change',
            'LIST_SHRS': 'Shares',
        }
        df = df.rename(columns=column_names)

        df['Date'] = pd.to_datetime(df['Date'])
        df['ChangeRate'] = pd.to_numeric(df['ChangeRate'].str.replace(',', ''))

        int_columns = [
            'Close',
            'UpDown',
            'Change',
            'Open',
            'High',
            'Low',
            'Volume',
            'Amount',
            'MarCap',
            'Shares'
        ]

        for col in int_columns:
            if col in df.columns:
                df[col] = pd.to_numeric(df[col].str.replace(',', ''), errors='coerce')

        df.set_index('Date', inplace=True)

        return df

# %%
krx_downloader = KrxHistoricalDailyPriceDataDownloader()
krx_data = krx_downloader.download(code)
krx_data
# Out:
#              Close  UpDown  Change  ChangeRate    Open    High     Low  \
# Date
# 2024-05-24   75900       2   -2400       -3.07   76800   77000   75700
# 2024-05-23   78300       1     600        0.77   77700   79100   77100
# 2024-05-22   77700       2    -700       -0.89   78100   78700   77300
# 2024-05-21   78400       2    -500       -0.63   78500   79000   78200
# 2024-05-20   78900       1    1500        1.94   78100   79100   77900
# ...            ...     ...     ...         ...     ...     ...     ...
# 1995-05-08  121000       2   -1000       -0.82  122000  122000  120500
# 1995-05-06  122000       2    -500       -0.41  122000  123500  122000
# 1995-05-04  122500       2   -1000       -0.81  124000  124500  122000
# 1995-05-03  123500       1    4000        3.35  119500  126500  119500
# 1995-05-02  119500       2   -1000       -0.83  121000  121000  118500
#
#               Volume         Amount           MarCap      Shares
# Date
# ...

# %%
import datetime
import numpy as np

def get_adjust_ratios(data):
    data = data.sort_index(ascending=False)
    adjust_ratios = []
    last_close = data['Close'].iloc[0]
    last_adjust_ratio = 1.0
    adjust_ratios.append(last_adjust_ratio)
    eleven_days = datetime.timedelta(days=11)
    for i in range(data.shape[0] - 1):
        if data.index[i] - data.index[i+1] > eleven_days:
            last_close = data['Close'].iloc[i+1]
            last_adjust_ratio = 1.0
        else:
            last_close = last_close - data['Change'].iloc[i] * last_adjust_ratio
            last_adjust_ratio = last_close / data['Close'].iloc[i+1]
        adjust_ratios.append(last_adjust_ratio)
    adjust_ratios = np.array(adjust_ratios)
    return adjust_ratios

def adjust_prices(data):
    data = data.sort_index(ascending=False)
    adjust_ratios = get_adjust_ratios(data)
    data['Adj Open'] = data['Open'] * adjust_ratios
    data['Adj High'] = data['High'] * adjust_ratios
    data['Adj Low'] = data['Low'] * adjust_ratios
    data['Adj Close'] = data['Close'] * adjust_ratios
    data['Adj Volume'] = data['Volume'] / adjust_ratios
    return data

krx_data = krx_downloader.download(code)
krx_data_adjusted = adjust_prices(krx_data)


fdr_data_adjusted_close = fdr_data.sort_index()['Close'].to_numpy()
yahoo_data_adjusted_close = yahoo_data.sort_index()['Adj Close'].reindex(fdr_data.index).to_numpy()
krx_data_adjusted_close = krx_data_adjusted.sort_index()['Adj Close'].reindex(fdr_data.index).to_numpy()

# %%
import matplotlib.pyplot as plt
plt.plot(fdr_data.index, fdr_data_adjusted_close)
plt.plot(fdr_data.index, yahoo_data_adjusted_close)

plt.legend(['fdr', 'yahoo'])
plt.show()

# %%
import yfinance as yf
yahoo_data = yf.download('%s.KS' % code)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
yahoo_data_adjusted_close = yahoo_data.sort_index()['Adj Close'].reindex(fdr_data.index).to_numpy()

# %%
import matplotlib.pyplot as plt
plt.plot(fdr_data.index, fdr_data_adjusted_close)
plt.plot(fdr_data.index, yahoo_data_adjusted_close)
plt.plot(fdr_data.index, krx_data_adjusted_close)

plt.legend(['fdr', 'yahoo', 'krx'])
plt.show()

# %%
import io
import requests
import pandas as pd

class YahooFinanceKrxHistoricalDailyPriceDataDownloader:

    def __init__(self):
        self._headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36',
        }

    def download(self, symbol, start_date=None, end_date=None):
        if start_date is None:
            start_date = pd.Timestamp(1990, 1, 1)
        elif not isinstance(start_date, pd.Timestamp):
            start_date = pd.Timestamp(start_date)
        if end_date is None:
            end_date = pd.Timestamp.now().normalize() + pd.Timedelta(1, unit='day')
        elif not isinstance(end_date, pd.Timestamp):
            end_date = pd.Timestamp(end_date)

        url = 'https://query1.finance.yahoo.com/v7/finance/download/%s.KS' % symbol.upper()
        params = {
            'period1': int(start_date.timestamp()),
            'period2': int(end_date.timestamp()),
            'interval': '1d',
            'events': 'history',
            'includeAdjustedClose': 'true',
        }
        response = requests.get(url, params=params, headers=self._headers)
        df = pd.read_csv(io.BytesIO(response.content), parse_dates=['Date'], index_col='Date')

        return df
yahoo_downloader = YahooFinanceKrxHistoricalDailyPriceDataDownloader()
yahoo_data = yahoo_downloader.download(code)

# %%
fdr_data = fdr.DataReader(code)
yahoo_data = yahoo_downloader.download(code)
krx_data = krx_downloader.download(code)

data = [
    fdr_data.index.to_series().describe(),
    yahoo_data.index.to_series().describe(),
    krx_data.index.to_series().describe()
    ]
keys = ['fdr', 'yahoo']
result = pd.concat(data, axis=1, keys=keys).T

result
# Out:
#       count                          mean        min                 25%  \
# fdr    6000 2012-03-26 22:47:16.800000000 2000-02-01 2006-03-06 18:00:00
# yahoo  6114 2012-01-18 19:41:51.874386688 2000-01-04 2005-11-11 18:00:00
#
#                       50%                 75%        max
# fdr   2012-03-15 12:00:00 2018-04-18 06:00:00 2024-05-24
# yahoo 2011-12-17 12:00:00 2018-03-06 18:00:00 2024-05-24

# %%
import matplotlib.pyplot as plt
plt.bar(keys, result['count'], color=['y','g'])

plt.show()

# %%
import os
import pandas as pd

# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/code/통계학과머신러닝PBL/data/KSXconst.csv')

# %%
df.tail()
# Out:
#      2004/01  2004/02  2004/03  2004/04  2004/05  2004/06  2004/07  2004/08  \
# 197  27840.0  27840.0  27840.0  27840.0  27840.0  27840.0  12200.0  17900.0
# 198  31820.0  31820.0  31820.0  31820.0  31820.0  31820.0   5070.0  12200.0
# 199   1020.0    180.0    180.0   9270.0   9270.0   9270.0  25530.0   5420.0
# 200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 201      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      2004/09  2004/10  ...   2023/03   2023/04   2023/05   2023/06  2023/07  \
# 197   4710.0  17300.0  ...   20000.0  381970.0  284740.0   57050.0  31430.0
# 198   5420.0   4710.0  ...  241590.0  284740.0  241590.0   20000.0  57050.0
# 199  12200.0   3660.0  ...   13890.0  241590.0   57050.0  241590.0  20000.0
# 200      NaN      NaN  ...       NaN       NaN       NaN       NaN      NaN
# 201      NaN      NaN  ...       NaN       NaN       NaN       NaN      NaN
#
# ...

# %%
for year in range(2004, 2024):
    start_col = (year - 2004) * 12
    end_col = start_col + 48
    exec(f"Close_{year} = [int(value) for value in list(set(df.iloc[:, start_col:end_col].dropna().values.flatten()))]")

# %%
Close_2004.__len__()
# Out:
# 275

# %%
# Close_2004 = [int(value) for value in list(set(df.iloc[:, :48].dropna().values.flatten()))]
# Close_2005 = [int(value) for value in list(set(df.iloc[:, 12:60].dropna().values.flatten()))]
# Close_2006 = [int(value) for value in list(set(df.iloc[:, 24:72].dropna().values.flatten()))]
# Close_2007 = [int(value) for value in list(set(df.iloc[:, 36:84].dropna().values.flatten()))]
# Close_2008 = [int(value) for value in list(set(df.iloc[:, 48:96].dropna().values.flatten()))]
# Close_2009 = [int(value) for value in list(set(df.iloc[:, 60:108].dropna().values.flatten()))]
# Close_2010 = [int(value) for value in list(set(df.iloc[:, 72:120].dropna().values.flatten()))]
# Close_2011 = [int(value) for value in list(set(df.iloc[:, 84:132].dropna().values.flatten()))]
# Close_2012 = [int(value) for value in list(set(df.iloc[:, 96:144].dropna().values.flatten()))]
# Close_2013 = [int(value) for value in list(set(df.iloc[:, 108:156].dropna().values.flatten()))]
# Close_2014 = [int(value) for value in list(set(df.iloc[:, 120:168].dropna().values.flatten()))]
# Close_2015 = [int(value) for value in list(set(df.iloc[:, 132:180].dropna().values.flatten()))]
# Close_2016 = [int(value) for value in list(set(df.iloc[:, 144:192].dropna().values.flatten()))]
# Close_2017 = [int(value) for value in list(set(df.iloc[:, 156:204].dropna().values.flatten()))]
# Close_2018 = [int(value) for value in list(set(df.iloc[:, 168:216].dropna().values.flatten()))]
# Close_2019 = [int(value) for value in list(set(df.iloc[:, 180:228].dropna().values.flatten()))]
# Close_2020 = [int(value) for value in list(set(df.iloc[:, 192:240].dropna().values.flatten()))]
# Close_2021 = [int(value) for value in list(set(df.iloc[:, 204:252].dropna().values.flatten()))]
# Close_2022 = [int(value) for value in list(set(df.iloc[:, 216:264].dropna().values.flatten()))]
# Close_2023 = [int(value) for value in list(set(df.iloc[:, 228:276].dropna().values.flatten()))]

# %%
Close_2004 = [str(item).zfill(6) for item in Close_2004]
Close_2005 = [str(item).zfill(6) for item in Close_2005]
Close_2006 = [str(item).zfill(6) for item in Close_2006]
Close_2007 = [str(item).zfill(6) for item in Close_2007]
Close_2008 = [str(item).zfill(6) for item in Close_2008]
Close_2009 = [str(item).zfill(6) for item in Close_2009]
Close_2010 = [str(item).zfill(6) for item in Close_2010]
Close_2011 = [str(item).zfill(6) for item in Close_2011]
Close_2012 = [str(item).zfill(6) for item in Close_2012]
Close_2013 = [str(item).zfill(6) for item in Close_2013]
Close_2014 = [str(item).zfill(6) for item in Close_2014]
Close_2015 = [str(item).zfill(6) for item in Close_2015]
Close_2016 = [str(item).zfill(6) for item in Close_2016]
Close_2017 = [str(item).zfill(6) for item in Close_2017]
Close_2018 = [str(item).zfill(6) for item in Close_2018]
Close_2019 = [str(item).zfill(6) for item in Close_2019]
Close_2020 = [str(item).zfill(6) for item in Close_2020]
Close_2021 = [str(item).zfill(6) for item in Close_2021]
Close_2022 = [str(item).zfill(6) for item in Close_2022]
Close_2023 = [str(item).zfill(6) for item in Close_2023]

# %%
import pandas as pd
import FinanceDataReader as fdr

for year in range(2007, 2010):
    valid_codes = []
    code_list = globals()[f'Close_{year}']

    for code in code_list:
        try:
            fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close']
            valid_codes.append(code)
        except:
            pass

    df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close'] for code in valid_codes]
    df = pd.concat(df_list, axis=1)
    df.columns = valid_codes

    globals()[f'Close_{year}'] = df

    # csv 파일로 저장
    df.to_csv(f'Close_{year}.csv')
# Out:
# "011020" invalid symbol or has no data
# "001830" invalid symbol or has no data
# "025930" invalid symbol or has no data
# "063350" invalid symbol or has no data

# %%
for year in range(2010, 2015):
    valid_codes = []
    code_list = globals()[f'Close_{year}']

    for code in code_list:
        try:
            fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close']
            valid_codes.append(code)
        except:
            pass

    df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close'] for code in valid_codes]
    df = pd.concat(df_list, axis=1)
    df.columns = valid_codes

    globals()[f'Close_{year}'] = df

    # csv 파일로 저장
    df.to_csv(f'Close_{year}.csv')

# %%
for year in range(2015, 2020):
    valid_codes = []
    code_list = globals()[f'Close_{year}']

    for code in code_list:
        try:
            fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close']
            valid_codes.append(code)
        except:
            pass

    df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close'] for code in valid_codes]
    df = pd.concat(df_list, axis=1)
    df.columns = valid_codes

    globals()[f'Close_{year}'] = df

    # csv 파일로 저장
    df.to_csv(f'Close_{year}.csv')

# %%
for year in range(2020, 2024):
    valid_codes = []
    code_list = globals()[f'Close_{year}']

    for code in code_list:
        try:
            fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close']
            valid_codes.append(code)
        except:
            pass

    df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+3}-12-31')['Close'] for code in valid_codes]
    df = pd.concat(df_list, axis=1)
    df.columns = valid_codes

    globals()[f'Close_{year}'] = df

    # csv 파일로 저장
    df.to_csv(f'Close_{year}.csv')

# %%
year = 2019
valid_codes = []
code_list = globals()[f'Close_{year}']

for code in code_list:
    try:
        fdr.DataReader(code, f'{year}-01-01', f'{year+4}-12-31')['Close']
        valid_codes.append(code)
    except:
        pass

df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+4}-12-31')['Close'] for code in valid_codes]
df = pd.concat(df_list, axis=1)
df.columns = valid_codes

globals()[f'Close_{year}_5'] = df

# csv 파일로 저장
df.to_csv(f'Close_{year}_5.csv')

# %%
year = 2018
valid_codes = []
code_list = globals()[f'Close_{year}']

for code in code_list:
    try:
        fdr.DataReader(code, f'{year}-01-01', f'{year+5}-12-31')['Close']
        valid_codes.append(code)
    except:
        pass

df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+5}-12-31')['Close'] for code in valid_codes]
df = pd.concat(df_list, axis=1)
df.columns = valid_codes

globals()[f'Close_{year}_6'] = df

# csv 파일로 저장
df.to_csv(f'Close_{year}_6.csv')

# %%
year = 2017
valid_codes = []
code_list = globals()[f'Close_{year}']

for code in code_list:
    try:
        fdr.DataReader(code, f'{year}-01-01', f'{year+6}-12-31')['Close']
        valid_codes.append(code)
    except:
        pass

df_list = [fdr.DataReader(code, f'{year}-01-01', f'{year+6}-12-31')['Close'] for code in valid_codes]
df = pd.concat(df_list, axis=1)
df.columns = valid_codes

globals()[f'Close_{year}_7'] = df

# csv 파일로 저장
df.to_csv(f'Close_{year}_7.csv')
